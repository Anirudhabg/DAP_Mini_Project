# %%
import pandas as pd

df = pd.read_excel('dataset.xlsx')

def search_bird(bird_name):
    bird_name = bird_name.lower()
    
    result = df[df['Name'].str.lower().str.contains(bird_name)]
    
    if not result.empty:
        return result
    else:
        print(f"No matching result found for '{bird_name}'.")

name_of_bird = input("Enter the name of bird: ")

res = search_bird(name_of_bird)
res.head(len(res))
# Out:
#    ID                    Name            Binomial name Conservation status  \
# 0   1  Black-footed albatross     Phoebastria nigripes     Near Threatened
# 1   2        Laysan albatross  Phoebastria immutabilis     Near Threatened
# 2   3         Sooty albatross         Phoebetria fusca          Endangered
#
#       Domain   Kingdom    Phylum Class              Order       Family  \
# 0  Eukaryota  Animalia  Chordata  Aves  Procellariiformes  Diomedeidae
# 1  Eukaryota  Animalia  Chordata  Aves  Procellariiformes  Diomedeidae
# 2  Eukaryota  Animalia  Chordata  Aves  Procellariiformes  Diomedeidae
#
#          Genus         Species  \
# 0  Phoebastria     P. nigripes
# 1  Phoebastria  P. immutabilis
# 2  Phoebastria        P. fusca
#
#                                          Description
# 0  The black-footed albatross is a small member o...
# 1  The Laysan albatross averages 81 cm (32 in) in...
# 2  The sooty albatross is a medium-sized albatros...

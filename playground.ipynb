# %%
import pandas as pd

df = pd.read_excel('dataset.xlsx')

def search_bird(bird_name):
    bird_name = bird_name.lower()
    
    result = df[df['Name'].str.lower().str.contains(bird_name)]
    
    if not result.empty:
        return result
    else:
        print(f"No matching result found for '{bird_name}'.")

name_of_bird = input("Enter the name of bird: ")

res = search_bird(name_of_bird)
res.head(len(res))
# res.head(len(res))["Description"]
# print(res["Description"])
# Out:
#     ID                     Name                  Binomial name  \
# 8    9       Brewer's blackbird         Euphagus cyanocephalus
# 9   10     Red-winged blackbird            Agelaius phoeniceus
# 10  11          Rusty blackbird             Euphagus carolinus
# 11  12  Yellow-headed blackbird  Xanthocephalus xanthocephalus
# 17  18          Spotted catbird           Ailuroedus maculosus
# 18  19             Gray catbird         Dumetella carolinensis
# 25  26          Bronzed cowbird               Molothrus aeneus
# 26  27            Shiny cowbird          Molothrus bonariensis
#
#    Conservation status     Domain   Kingdom    Phylum Class          Order  \
# 8        Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 9        Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 10          Vulnerable  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 11       Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 17       Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 18       Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 25       Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
# 26       Least Concern  Eukaryota  Animalia  Chordata  Aves  Passeriformes
#
#                Family           Genus            Species  \
# 8           Icteridae        Euphagus   E. cyanocephalus
# 9           Icteridae        Agelaius      A. phoeniceus
# 10          Icteridae        Euphagus       E. carolinus
# 11          Icteridae  Xanthocephalus  X. xanthocephalus
# 17  Ptilonorhynchidae      Ailuroedus       A. maculosus
# 18            Mimidae       Dumetella    D. carolinensis
# 25         Icteriidae       Molothrus          M. aeneus
# 26         Icteriidae       Molothrus     M. bonariensis
#
#                                           Description
# 8   Brewer's blackbird (Euphagus cyanocephalus) is...
# 9   The red-winged blackbird (Agelaius phoeniceus)...
# 10  The rusty blackbird (Euphagus carolinus) is a ...
# 11  The yellow-headed blackbird (Xanthocephalus xa...
# 17  The spotted catbird (Ailuroedus maculosus) is ...
# 18  The gray catbird (Dumetella carolinensis), als...
# 25  The bronzed cowbird (Molothrus aeneus), once k...
# 26  The shiny cowbird (Molothrus bonariensis) is a...
